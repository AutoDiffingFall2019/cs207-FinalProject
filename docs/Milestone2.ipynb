# %%
import numpy as np
class Dual_number:
    #Dual number class, user may specify initial value or not during allocation. It can be a vector or a number
    def __init__(self, real_part=None,imag_part=None):
        If type(input_value) == str:#Input value data type check
            raise(ValueError('The input cannot be string'))
        elif: #If input type is list/tuple/np.array, data type convection
            try:
                val = int(userInput)
            except ValueError:
                print("Input cannot be converted to number!")
            real_part=np.array(float(real_part))
            imag_part=np.array(float(imag_part))
        self.real=real_part
        self.imag=imag_part
        
def data_type_check(x):
    try float(x.value)+float(x.der)
    except ValueError:
        print("Input has to have attributes x.value and x.der")
    
class AD_fun():
    #Automatic differentiation function class.
    def __init__(self):
        self.fun_value=None#Define the function value
        self.fun_grad=None#Define the function gradient

    def exp(self,input_value):#Define exponential function for dual numbers
        #Input data type check, raise error when it is not dual number or another AD function
        if type(input_value) == type(Dual_number()): # If input is a number
            fun_value=np.exp(dual_number.real)
            fun_grad_value=np.exp(dual_number.real)*dual_number.imag
            return #another dual number with dual.real=fun_value, dual.imag=fun_grad_value
        elif type(input_value) == type(AD_fun()):# If input is another AD function
            #Decorate the input function with another layer:
            def decorated_input(input_fun):
                decorated_input_fun.value=np.exp(input_fun.value)
                decorated_input_fun.grad=np.exp(input_fun.value)*input_fun.grad            
            return decorated_input
        else:
            raise(ValueError('The input has to be dual number or another function'))
            
    def __add__(self,second_value):#Override default adding with dunder method
        #Input data type check, raise error when it is not dual number or another AD function
        if second_value == a dual number: # If input is a number
            fun_value=self.value+second_value.value
            fun_grad_value=self.value+second_value.grad
            return #another dual number with dual.real=fun_value, dual.imag=fun_grad_value
        elif input_value == another AD function:# If input is another AD function
            #Decorate the input function with another layer:
            def decorated_input(input_fun):
                decorated_input_fun.value=self.value+second_value.value  
                decorated_input_fun.grad =self.grad +second_value.grad         
            return decorated_input_fun
    def __radd__(self,second_value):# This class should be able to handle left and right add
        return self.__add__(self,second_value)
    def __mul__(self,second_value):#Similarly, we can overrider mutiply
    def __rmul__(self,second_value):#Similarly, we can overrider mutiply
    def __sub__(self,second_value):#Similarly, we can overrider substraction
    def __rsub__(self,second_value):#Similarly, we can overrider substraction
    def sin(self,x):#Similarly, we can give user defined sin function, 
        fun.value=sin(x.value)
        fun.grad=cos(x.value)*x.grad
    def cos(self,x):#Similarly, we can give user defined cos function, 
    def log(self,x):#Similarly, we can give user defined log function, 
    def power(self,x,order):#Similarly, we can give user defined power function, 
    def evaluation(fun,value):#This evaulate the given function at given point
        #only needed if value is not given when defining function
        #Datatype checking here, raise error when needed
        result=fun(value)
        return (result.value,result.grad)
    
class paralized(AD_fun):
    # To deal with  vector of functions with vector input, we make sure our scaler functions work with vector input.
    # Then here we loop over function vectors, evaluate each function, and return the result vector
    result=[]
    for function in function_vectors:
        result.append(function.evaluation)
    return results
class post_process():
    #Visualization goes here
